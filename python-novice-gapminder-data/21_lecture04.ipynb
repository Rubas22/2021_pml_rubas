# %% [markdown]
# Con el método DessionTreeClassifier (árboles de decisión) aplicado a la clasificación del cáncer, ¿Cuál es su precisión en el conjunto de prueba si modificamos la profundidad del árbol a 5 con la semilla aleatoria random_state=0? Poner respuesta a 3 decimales

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
 cancer.data, cancer.target, stratify=cancer.target, random_state=42)

tree = DecisionTreeClassifier(max_depth=5, random_state=0)
tree.fit(X_train, y_train)

print("Accuracy on test set: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Accuracy on test set: 0.951

# %% [markdown]
# Con el método RandomForestClassifier aplicado a la clasificación del cáncer,  si modificamos el número de árboles a 75, entonces la característica más relevante en la clasificación es:

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import numpy as np

forest = RandomForestClassifier(n_estimators=75, random_state=0)
forest.fit(X_train, y_train)

def plot_feature_importances_cancer(model):
 n_features = cancer.data.shape[1]
 plt.barh(range(n_features), model.feature_importances_, align='center')
 plt.yticks(np.arange(n_features), cancer.feature_names)
 plt.xlabel("Feature importance")
 plt.ylabel("Feature")

plot_feature_importances_cancer(forest)
